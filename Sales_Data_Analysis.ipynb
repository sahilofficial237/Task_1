# %% [markdown]
# <a href="https://colab.research.google.com/github/sahilofficial237/Task_1/blob/main/Sales_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files

print("📂 Upload your CSV file:")
uploaded = files.upload()

file_name = list(uploaded.keys())[0]
df = pd.read_csv(file_name)

print("\n✅ Dataset Loaded Successfully!\n")
print("🔹 First 5 Rows:")
display(df.head())

print("\n🔹 Dataset Info:")
print(df.info())

print("\n🔹 Missing Values:")
print(df.isnull().sum())

print("\n🔹 Statistical Summary:")
display(df.describe())


if 'Product' in df.columns and 'Sales' in df.columns:
    sales_by_product = df.groupby('Product')['Sales'].sum().reset_index()
    print("\n💰 Total Sales by Product:")
    display(sales_by_product)

    # Plot - Sales by Product
    plt.figure(figsize=(8,5))
    sns.barplot(x='Product', y='Sales', data=sales_by_product, palette='viridis')
    plt.title('Total Sales by Product')
    plt.xlabel('Product')
    plt.ylabel('Sales')
    plt.show()

if 'Region' in df.columns and 'Sales' in df.columns:
    sales_by_region = df.groupby('Region')['Sales'].sum().reset_index()
    print("\n📍 Total Sales by Region:")
    display(sales_by_region)

    # Plot - Sales Distribution by Region (Pie Chart)
    plt.figure(figsize=(6,6))
    plt.pie(sales_by_region['Sales'], labels=sales_by_region['Region'], autopct='%1.1f%%', startangle=90)
    plt.title('Sales Distribution by Region')
    plt.show()

print("""
📈 Basic Data Insights:
- Shows total sales per product and per region.
- Visual charts help identify top-performing categories or regions.
- You can modify the column names and groupings as needed.
""")
# Out:
# 📂 Upload your CSV file:
#      <input type="file" id="files-9a9af67e-7e43-4996-a29f-c08992754693" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9a9af67e-7e43-4996-a29f-c08992754693">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...
